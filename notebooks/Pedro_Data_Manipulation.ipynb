# %% [markdown]
# ## Pedro - Data Manipulation
#
# #### Look into coordinates matching

# %%
# %load_ext lab_black

# %%
import pandas as pd
import geopandas
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-c9c6ea50dbe8> in <module>
#       1 import pandas as pd
# ----> 2 import geopandas
#
# ~\anaconda3\envs\geodataenvironment\lib\site-packages\geopandas\__init__.py in <module>
# ----> 1 from geopandas._config import options  # noqa
#       2
#       3 from geopandas.geoseries import GeoSeries  # noqa
#       4 from geopandas.geodataframe import GeoDataFrame  # noqa
#       5 from geopandas.array import points_from_xy  # noqa
#
# ~\anaconda3\envs\geodataenvironment\lib\site-packages\geopandas\_config.py in <module>
#     124 use_pygeos = Option(
#     125     key="use_pygeos",
# --> 126     default_value=_default_use_pygeos(),
#     127     doc=(
#     128         "Whether to use PyGEOS to speed up spatial operations. The default is True "
#
# ...

# %% [markdown]
# #### Upload data sets

# %%
df = pd.read_csv("../src/data/GeoFeatures_Zurich_provided_by_UrbanDataLabs.csv")

# %%
df_migros = pd.read_csv(
    "notebooksdetailed_Migros_python_mined.csv",
    names=[
        "Name",
        "Address",
        "Lat",
        "Lon",
        "keywords",
        "store_id",
        "Postal Code",
        "Full Address",
        "url_to_store",
    ],
)

# %%
df_migros
# Out:
#                                    Name  \
# 0                     Migros Supermarkt
# 1                       Denner Discount
# 2                     Migros Supermarkt
# 3                      Migros Take Away
# 4           migrolino Zrich Waffenplatz
# ..                                  ...
# 190                migrolino Glattbrugg
# 191          migrolino fresh Glattbrugg
# 192             Coop Supermarkt Opfikon
# 193  Coop Supermarkt Glattbrugg Bahnhof
# 194                     Denner Discount
#
#                                            Address        Lat       Lon  \
# 0                    Zrcherstrasse 15, Birmensdorf  47.354330  8.436892
# 1    Areal Sternen, Zrcherstrasse 110, Birmensdorf  47.359685  8.454051
# 2           BRUNAUPARK, Giesshbelstrasse 65, Zrich  47.358386  8.517647
# 3                       Giesshbelstrasse 65, Zrich  47.358215  8.517397
# 4                     Waffenplatzstrasse 40, Zrich  47.359510  8.526613
# ...

# %%
geopandas.read_file("../src/data/Zürich_data_request_1e23094c-0cb5-11ec-a458-005056b0ce82/data/stzh.adm_statzonen_map.shp")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-1f12cb8433d0> in <module>
# ----> 1 geopandas.read_file("../src/data/Zürich_data_request_1e23094c-0cb5-11ec-a458-005056b0ce82/data/stzh.adm_statzonen_map.shp")
#
# NameError: name 'geopandas' is not defined
